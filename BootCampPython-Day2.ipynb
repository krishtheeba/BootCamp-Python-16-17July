# %%
Recap
=====
Variables
Datatypes- int, str, float, List,Tuple,byte,bool
String- str- immutable -ordered - collection of characters - indexing, slicing,methods- strip(), split(), str()
List - [] - mutable - ordered - collection of elements - indexing, slicing, methods- append(),insert(),count(),pop(),remove()
    - modify  Listname[index]=new_value

Tuple - () - immutable - ordered - indexing- slicing- methods-count(),index()

File handling- open(filename,mode)  mode- 'r'  or  'w'   or 'a'

# %%
with open("E:/OU-BootCamp/New_employee.txt", 'r') as fd:  # read mode
    print(fd.read())
# Out:
# DATA

# %%
with open("E:/OU-BootCamp/New_employee.txt", 'w') as fd:  # write mode
    print(fd.write("Arun,Sales,Hyderabad,723872\n"))
# Out:
# 28

# %%
with open("E:/OU-BootCamp/New_employee.txt", 'r') as fd:  # read mode
    print(fd.read())
# Out:
# Arun,Sales,Hyderabad,723872

# %%
with open("E:/OU-BootCamp/New_employee.txt", 'a') as fd:  # append mode
    print(fd.write("Shalini,Prod,Hyderabad,723872\n"))
# Out:
# 30

# %%
with open("E:/OU-BootCamp/New_employee.txt", 'r') as fd:  # read mode
    print(fd.read())
# Out:
# Arun,Sales,Hyderabad,723872
# Shalini,Prod,Hyderabad,723872

# %%
Operator
========

1. Arithmetic Operator -       + - * / // %     (int,float)-> (int/float)
2. Str Operator     -         +   *   
3. Relational Operator   -     <   >  <=   >=   ==  !=  (int,float,str)---> bool 
eg.   10>20    ->  False

4. membership operator      in       not in       bool output
5. logical operator operator   and   or   not     (relational exps(bool)  ---> bool)
and operator
------------
R1  R2   O
T   T    T
T   F     F
F   F     F
F   T     F
     -> True when both are True
-------------------------------
or Operator  -> False when both False
-----------

R1  R2  O
T    F   T
F    T   T
T    T   T
F     F  F
-------------------------------------
not opertor

# %%
print(10 > 20)
# Out:
# False

# %%
print("python" == "PythON")
# Out:
# False

# %%
print(12.33 >=  12.342)
# Out:
# False

# %%
"s"  in "seashore"
# Out:
# True

# %%
"s"  not in "seashore"
# Out:
# False

# %%
# Conditional Statements
#-----------------------
# Test any condition, validation purpose
#
# condition matches----> execute one set of statement
#   |------Not match --> execute some default statement

# 3 Types
#========
# 1. simple if
#---------------
#  if (condition- relational exp):
#         True statement
#======================================
#  2.if  else statement
#-------------------
#  if (condition- relational exp):
#         True statement
#  else:
#          False statement
#3. if.. elseif.. else

# %%
# simple if statement

if(10 < 20):
    print("10 less than 20")
# Out:
# 10 less than 20

# %%
# simple if statement

if(10 > 20):
    print("10 less than 20")

# %%
#  if  else statement

if(10 > 20):  # False
    print("10 greater than 20")
else:
    print("10 less than 20")
# Out:
# 10 less than 20

# %%
#Task
#-----
# step 1: create a List with values  "host1","host2","host3" 
# step 2: Read an input hostname from user. eg) "host2" and store it in a variable.
# step 3: check whether user input is in List elements     (eg.  membership operator-   useri/p    in  List )
# step 4: If user input exist in List, display "Hostname already exist"
# step 5: Else display "Hostname Not Available"

# %%
Hostnames=["host1","host2","host3"]
host= input("Enter the Hostname")

if( host in Hostnames):
    print("Hostname already Exist")
else:
    print("Hostname Not Available")
# Out:
# Enter the Hostname host2
# Hostname already Exist

# %%
Hostnames=["host1","host2","host3"]
host= input("Enter the Hostname")

if( host in Hostnames):
    print("Hostname already Exist")
else:
    print("Hostname Not Available")
# Out:
# Enter the Hostname host3000
# Hostname Not Available

# %%
username=input("Enter Username")

if username="root":
    print("root User")
else:
    print("Non-root User")

# %%
username=input("Enter Username")

if(username=="root"):  # condition1
    print("root User")
elif (username =="student"):#condition2
    print("student User")
else:
    print("Non-root User")
# Out:
# Enter Username student
# student User

# %%
'''
Task
====
Step1:  Declare pin=1234
Step 2: Read a user input PIN.
Step 3: Check whether PIN matches with pin.
Step 4: If Matched, display " PIN MATCHED SUCCESSFULLY"
Step 5: Else display "PIN MATCH FAILED"

'''

# %%
"bash" --> S1
"winX"  --> S2
"Ubuntu" --> S3
------------------------> if.. elif...else

"bash"  or   "winx"   or  "Ubuntu" ---> S1
-------------------------------------------------> Logical operator-> condition

# %%
user_input=input("Enter a shellname/ Os name")

if user_input=="bash"   or   user_input=="winx"  or user_input=="Ubuntu":
    print("matched")
else:
    print("Not matched")
# Out:
# Enter a shellname/ Os name bash
# matched

# %%
user_input=input("Enter a shellname/ Os name")

if user_input=="bash"   or   user_input=="winx"  or user_input=="Ubuntu":
    print("matched")
else:
    print("Not matched")
# Out:
# Enter a shellname/ Os name winx
# matched

# %%
user_input=input("Enter a shellname/ Os name")

if user_input=="bash"   or   user_input=="winx"  or user_input=="Ubuntu":
    print("matched")
else:
    print("Not matched")
# Out:
# Enter a shellname/ Os name Ubuntu
# matched

# %%
user_input=input("Enter a shellname/ Os name")

if user_input=="bash"   or   user_input=="winx"  or user_input=="Ubuntu":
    print("matched")
else:
    print("Not matched")
# Out:
# Enter a shellname/ Os name ksh
# Not matched

# %%
#  Options --> or operator
# Range  --> 5000 - 6000
     #     port > 5000    and  port < 60000

# %%
'''
Task 1
======
Step 1: Read a Port Number from User as input.
Step 2: Check whether Port Number is within range 5000 - 6000.
Step 3: If Port Number is in the range, display "Valid Port Number"
Step 4: Else display "Invalid Port Number"
=================================================================================================================
Task2
=====
slide 78 in PPT - Python-Level1
----------------------------------
Write a python program – if elif else
Step 1: create file name p7.py
Step 2: Read a shell name from <STDIN>
Step 3: If input shell name is bash, initialize profile file name as “bashrc”
Step 4: If input shell name is ksh, initialize profile filename as “kshrc”
Step 5: If input shell name is psh, initialize profile filename as “winprofile”
Step 6: If neither of the shell name matches, Initialize with default shell name as “nologin” and profile file name  
                                                                                             as “/etc/profile” 
Step 7 : Display shell name and shell profile filename 


'''

# %%
'''
Task1
======
Step 1: Read a Port Number from User as input.
Step 2: Check whether Port Number is within range 5000 - 6000.
Step 3: If Port Number is in the range, display "Valid Port Number"
Step 4: Else display "Invalid Port Number"
'''
port= int(input("Enter a Port Number"))
if port > 5000 and port < 6000:
    print("Valid Port Number")
else:
    print("Invalid Port Number")
# Out:
# Enter a Port Number 5001
# Valid Port Number

# %%
port= int(input("Enter a Port Number"))
if port > 5000 and port < 6000:    #  True and False--> False
    print("Valid Port Number")
else:
    print("Invalid Port Number")
# Out:
# Enter a Port Number 6050
# Invalid Port Number

# %%
'''
Task2
=====
slide 78 in PPT - Python-Level1
----------------------------------
Write a python program – if elif else
Step 1: create file name p7.py
Step 2: Read a shell name from <STDIN>
Step 3: If input shell name is bash, initialize profile file name as “bashrc”
Step 4: If input shell name is ksh, initialize profile filename as “kshrc”
Step 5: If input shell name is psh, initialize profile filename as “winprofile”
Step 6: If neither of the shell name matches, Initialize with default shell name as “nologin” and profile file name  
                                                                                             as “/etc/profile” 
Step 7 : Display shell name and shell profile filename 


'''
shell= input("Enter a shell name")
if shell=="bash":
    profile="bashrc"
elif shell=="ksh":
    profile="kshrc"
elif shell=="psh":
    profile="winprofile"
else:
    shell="nologin"
    profile="/etc/profile"
print(f"ShellName:{shell} \t ProfileFileName:{profile}")
# Out:
# Enter a shell name bash
# ShellName:bash 	 ProfileFileName:bashrc

# %%
shell= input("Enter a shell name")
if shell=="bash":
    profile="bashrc"
elif shell=="ksh":
    profile="kshrc"
elif shell=="psh":
    profile="winprofile"
else:
    shell="nologin"
    profile="/etc/profile"
print(f"ShellName:{shell} \t ProfileFileName:{profile}")
# Out:
# Enter a shell name ksh
# ShellName:ksh 	 ProfileFileName:kshrc

# %%
shell= input("Enter a shell name")
if shell=="bash":
    profile="bashrc"
elif shell=="ksh":
    profile="kshrc"
elif shell=="psh":
    profile="winprofile"
else:
    shell="nologin"
    profile="/etc/profile"
print(f"ShellName:{shell} \t ProfileFileName:{profile}")
# Out:
# Enter a shell name psh
# ShellName:psh 	 ProfileFileName:winprofile

# %%
shell= input("Enter a shell name")
if shell=="bash":
    profile="bashrc"
elif shell=="ksh":
    profile="kshrc"
elif shell=="psh":
    profile="winprofile"
else:
    shell="nologin"
    profile="/etc/profile"
print(f"ShellName:{shell} \t ProfileFileName:{profile}")
# Out:
# Enter a shell name sh
# ShellName:nologin 	 ProfileFileName:/etc/profile

# %%
'''
Looping Statements - execute statement more than once
==================
1. Condition Based Looping  - while
syntax:-
=======
Step1: Initialization_Counter_Variable
Step2: while(Condition):
        statement
        Step3: Increment/decrement Counter_Variable

2. Collection Based Looping - for

for Element in Collection:
    statement

'''

# %% [raw]
# #1. Condition based Looping
#
# count=0
# while(count <3):
#     print("Hello All")
#     count=count + 1
#
# '''
# initialization-> only once
#
# condition and increment (repeat)
#
# count=0     0<3-> True  'Hello All'   count=1        Iteration-1
#             1<3-> True   'Hello All'   count=1+1=2    Iteration-2
#             2<3-> True   'Hello All'    count=2+1=3   Iteration-3
#             3<3-> False-> Terminates While Loop
# '''

# %%
count=0
while(count <3):
    print("Hello All")
    count=count + 1
# Out:
# Hello All
# Hello All
# Hello All

# %%
count=0
while count <3:
    print("Hello All")
    #count=count + 1
    count+=1          #   compound Assignment operator  i+=1    is same as  i=i+1
# Out:
# Hello All
# Hello All
# Hello All

# %%
count=3
while count > 0:
    print("Hello All")
    #count=count - 1
    count-=1
# Out:
# Hello All
# Hello All
# Hello All

# %%
'''
Expected Output
---------------
1. Data
2. Data
3. Data
'''
count=1
while count<=3:
    print(f"{count}. Data")
    count+=1
# Out:
# 1. Data
# 2. Data
# 3. Data

# %%
'''
1. Data
3. Data
'''
#continue- skips the remaining part and continues with next iteration

# %%
count=1
while count<=3:   # 1<=3   2<=3
         
    if count==2:  # 1==2    2==2
        count+=1         
        continue
    else:
        print(f"{count}. Data")
        count+=1
# Out:
# 1. Data
# 3. Data

# %%
# break- exit from loop
# exit() - exit from python scrip

count=1
while count<=5:
    print(f"{count}. Data")
    count+=1
# Out:
# 1. Data
# 2. Data
# 3. Data
# 4. Data
# 5. Data

# %%
count=0
while count<=5:
    
    if count==2:
        break
    print(f"{count+1}. Data")
    count+=1
# Out:
# 1. Data
# 2. Data

# %%
# Modify Pin Testing to read input from user THRICE. 
# If Pin matches, apply break to come out of loop.

# %%
PIN=1234
count=0
while count<3:
    pin=int(input("Enter PIN"))
    if PIN==pin:
        print("PIN Matched")
        break
    else:
        print("PIN Not Matched")
    count+=1
# Out:
# Enter PIN 222
# PIN Not Matched
# Enter PIN 3222
# PIN Not Matched
# Enter PIN 1234
# PIN Matched

# %%
PIN=1234
count=0
while count<3:
    pin=int(input("Enter PIN"))
    if PIN==pin:
        print("PIN Matched")
        break
    else:
        print("PIN Not Matched")
    count+=1

if pin != PIN:
    print ("PIN Blocked")
# Out:
# Enter PIN 44334
# PIN Not Matched
# Enter PIN 34343
# PIN Not Matched
# Enter PIN 34343
# PIN Not Matched
# PIN Blocked

# %%
# 2. Collection Style Loop
s="Python Programming"

for var in s:  # str as Collection
    print(var)
# Out:
# P
# y
# t
# h
# o
# n
#
# P
# r
# o
# g
# r
# a
# m
# m
# i
# n
# g

# %%
L=[1,2,3,4,5,6]  # List as Collection
for i in L:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
T=(1,2,3,4,5,6)  # Tuple as Collection
for i in T:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
# Task - slide no. 89   &  90
'''
Task1:
----
Step 1: create a file name: p9.py
Given String 
S=“123456578”
Step 2: Calculate sum of numbers

Note : use for loop
==============================================
Task2:
------
Write a python program
Step 1: create a new file p10.py
Step 2: Modify the below code using while loop 
s=“abcd”
for var in s:
    print(var)

Step 3: Display list of characters one by one

'''

# %%
#Task1
S="123456578"
sum=0
for i in S:
    sum += int(i)
print(sum)
# Out:
# 41

# %%
#Task2
S="abcd"
i=0
while(i<len(S)):
    print(S[i])
    i+=1
# Out:
# a
# b
# c
# d

# %%
# dictionary - dict- help(dict)

# List-mutable -ordered- index- allows duplicates - []
# Tuple- immutable - ordered - index - allows duplicates-()
# dict -mutable -{key:value, ...} - unordered - key based access - allows duplicates in value, keys are unique
#                 |-------|
#                  item1

# %%
d={} # empty dict
print(d,type(d))
# Out:
# {} <class 'dict'>

# %%
d={"key1":"value1","key2":"value2"}
# syntax:- To access value 
# dictname[Existing_key]

# %%
d["key1"]
# Out:
# 'value1'

# %%
print(d)
# Out:
# {'key1': 'value1', 'key2': 'value2'}

# %%
d["key100"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 d["key100"]
#
# KeyError: 'key100'

# %%
''
NameError
AttributeError
ValueError
KeyError
IndentationError
'''

# %%
#Task
=====
Step1: create Empty dict
Step2: Read IpAddress and HostName from user
Step3: Use HostName as key and IPAddress as Value , add an entry to the existing dict
Step 4: display dict

# %%
d={"Host1":"22.12.11.22", "Host2":"2.32.1.2"}
#print(d)
for i in d:   # i -> key
    print(f"HostName:{i}\t IPAddress:{d[i]}")
# Out:
# HostName:Host1	 IPAddress:22.12.11.22
# HostName:Host2	 IPAddress:2.32.1.2

# %%
d={}
i=0
while(i<3):
    Host=input("Enter Hostname")
    IP=input("Enter IP Address")
    d[Host]=IP   # add entry to Dictionary
    i+=1

for key in d:
    print(f"HostName:{key}\tIPAddress:{d[key]}")
# Out:
# Enter Hostname Host01
# Enter IP Address 192.168.1.2
# Enter Hostname Host02
# Enter IP Address 1.2.3.4
# Enter Hostname Host03
# Enter IP Address 168.192.2.1
# HostName:Host01	IPAddress:192.168.1.2
# HostName:Host02	IPAddress:1.2.3.4
# HostName:Host03	IPAddress:168.192.2.1

# %%
d={}
i=0
while(i<3):
    Host=input("Enter Hostname")
    IP=input("Enter IP Address")
    d[Host]=IP   # add entry to Dictionary if key not exist/ modify existing value with new value if key already exist
    i+=1

for key in d:
    print(f"HostName:{key}\tIPAddress:{d[key]}")
# Out:
# Enter Hostname Host01
# Enter IP Address 192.179.1.2
# Enter Hostname Host01
# Enter IP Address 1.2.3.4
# Enter Hostname Host02
# Enter IP Address 2.1.2.1
# HostName:Host01	IPAddress:1.2.3.4
# HostName:Host02	IPAddress:2.1.2.1

# %%
                            KeyBased                           VS   Method

To  get value            dictname[Key]-> Value/Keyerror           dictname.get(key)--> value/ None

# %%
d.get("Host01")
# Out:
# '1.2.3.4'

# %%
d["Host01"]
# Out:
# '1.2.3.4'

# %%
d
# Out:
# {'Host01': '1.2.3.4', 'Host02': '2.1.2.1'}

# %%
d.pop("Host01")
# Out:
# '1.2.3.4'

# %%
d
# Out:
# {'Host02': '2.1.2.1'}

# %%
# How to dleete whole dict   -> del(dict)

del(d)

# %%
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 d
#
# NameError: name 'd' is not defined

# %%
d={"k1":"v1","k2":"v2"}
d
# Out:
# {'k1': 'v1', 'k2': 'v2'}

# %%
help(d.setdefault)
# Out:
# Help on built-in function setdefault:
#
# setdefault(key, default=None, /) method of builtins.dict instance
#     Insert key with a value of default if key is not in the dictionary.
#
#     Return the value for key if key is in the dictionary, else default.

# %%
d.setdefault("k3","v5")
d
# Out:
# {'k1': 'v1', 'k2': 'v2', 'k3': 'v5'}

# %%
d.setdefault("k3","v7")
d
# Out:
# {'k1': 'v1', 'k2': 'v2', 'k3': 'v5'}

# %%
# set
S=set()
print(S,type(S))
# Out:
# set() <class 'set'>

# %%
Function
  - reusuable code
  - 2 parts
        - Function Definition
        - Function Call

  - syntax:-  Function Definition
        def functionName():
            statements
  - synatx:-  Function Call
        functionName()

# %%
# Function Definition
def f1():
    print("Inside f1")

# %%
# Function Call
f1()
# Out:
# Inside f1

# %%
type(f1)
# Out:
# function

# %%
f1
# Out:
# <function __main__.f1()>

# %%
f1()  # this is function call
# Out:
# Inside f1

# %%
def f1():
    print("Inside f1")   # 2nd statemnet

def f2():
    print("Inside f2")

f1()  # 1st line 
f2()
f1()
# Out:
# Inside f1
# Inside f2
# Inside f1

# %%
def f1():
    print("Inside f1")   # 2nd statemnet
    return 10
    
rv=f1()  # 1st line 

print(rv)
# Out:
# Inside f1
# 10

# %%
Step 1: create a function that returns a list
Step 2: In main script, display the type of returned value

# %%
def f():
    return [1,2,3,4]
rv=f()
print(type(rv))
print(type(f))
# Out:
# <class 'list'>
# <class 'function'>

# %%
def f():
    k=10

f()
print(k)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 5
#       2     k=10
#       4 f()
# ----> 5 print(k)
#
# NameError: name 'k' is not defined

# %%
def f():   # way 1 - making var available to outside function - using global
    global k
    k=10

f()
print(k)
# Out:
# 10

# %%
def f():   # way 2 - making var available to outside function - using return
    j=10
    return j
rv=f()
print(rv)
# Out:
# 10

# %%
# Function with input
def f(a):               # Required Argument
    print(a, type(a))

# %%
f(1.33)
# Out:
# 1.33 <class 'float'>

# %%
f(10)
# Out:
# 10 <class 'int'>

# %%
f("data")
# Out:
# data <class 'str'>

# %%
f([1,2,3,4])
# Out:
# [1, 2, 3, 4] <class 'list'>

# %%
f()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 f()
#
# TypeError: f() missing 1 required positional argument: 'a'

# %%
# Default Arg
def f(b=10):   # b-> default arg
    print(b,type(b))

# %%
f(100)
# Out:
# 100 <class 'int'>

# %%
f() # without input- default value is used
# Out:
# 10 <class 'int'>

# %%
def f(a,b=10):  # order-> required arg, default arg
    print(a,type(a))
    print(b,type(b))

# %%
f(1,2)
# Out:
# 1 <class 'int'>
# 2 <class 'int'>

# %%
def f(b=10,a):  # order-> Error
    print(a,type(a))
    print(b,type(b))
# Out:
#   Cell In[85], line 1
#     def f(b=10,a):  # order-> Error
#                ^
# SyntaxError: parameter without a default follows parameter with a default

# %%
def f1(*a):  # variable length arg
    print(a,type(a))

f1(1)
# Out:
# (1,) <class 'tuple'>

# %%
f1(1,2,3,4)
# Out:
# (1, 2, 3, 4) <class 'tuple'>

# %%
f1()
# Out:
# () <class 'tuple'>

# %%
def f2(a,b=10,*c):
    print(a,type(a))
    print(b,type(b))
    print(c,type(c))

# %%
f2(1)
# Out:
# 1 <class 'int'>
# 10 <class 'int'>
# () <class 'tuple'>

# %%
# !pip install <modulename>
-------------
cmd prompt
pip install <modulename>
