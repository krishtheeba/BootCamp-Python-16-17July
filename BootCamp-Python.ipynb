# %%
print("hello")
# Out:
# hello

# %%
var = 10  # var - namespace  10- obj of class <int>

# %%
print(var)
# Out:
# 10

# %%
type(var)  # determines type of var
# Out:
# int

# %%
print(id(10))
print(id(7+3))
print(id(var))
# Out:
# 140704741569736
# 140704741569736
# 140704741569736

# %%
print(id(260))
b=260
print(id(b))
# Out:
# 2689592351216
# 2689592351920

# %%
help(int)   # Single Line Comment
# help(10)
# Out:
# Help on class int in module builtins:
#
# class int(object)
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating-point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Built-in subclasses:
#  |      bool
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
# ...

# %%
f=10.55
print(type(f))
# Out:
# <class 'float'>

# %%
class ABC:
    f=1.33

obj= ABC()  # Object Creation
print(obj.F) # variable inside class
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 5
#       2     f=1.33
#       4 obj= ABC()  # Object Creation
# ----> 5 print(obj.F)
#
# AttributeError: 'ABC' object has no attribute 'F'

# %%
print(type(F))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 print(type(F))
#
# NameError: name 'F' is not defined

# %%
fname="Theeba"
lname='K'
print(type(fname))
print(type(lname))  # help(str)  or help('')   or help("")  or help(lname)
# Out:
# <class 'str'>
# <class 'str'>

# %%
print(fname)
print(lname)
# Out:
# Theeba
# K

# %%
print(fname, lname)
# Out:
# Theeba K

# %%
# User defined str  +  variable
# comma
print("My name is ", fname,lname)   # Way 1

# c style
print("My name is %s" %(fname))
print("My name is %s %s" %(fname,lname))   # way 2
# Out:
# My name is  Theeba K
# My name is Theeba
# My name is Theeba K

# %%
# python oop style- format method of string
print("My name is {} ".format(fname))   # object.method()   # Way 3

print("My name is {} {}".format(fname,lname))
name=fname+lname
print("My name is {}".format(name))
# Out:
# My name is Theeba
# My name is Theeba K
# My name is TheebaK

# %%
name=fname + " " + lname
print("My name is {}".format(name))
# Out:
# My name is Theeba K

# %%
print(f'My name is {fname}')
# Out:
# My name is Theeba

# %%
print(f"My name is {name}")
# Out:
# My name is Theeba K

# %%
name="Theeba"
city="Bglore"
cost=22222.66

print(f"Iam {name} working in {city} with cost {cost}")
# Out:
# Iam Theeba working in Bglore with cost 22222.66

# %%
====================
Iam Theeba
--------------------
Working in Bglore
-------------------
with cost 322.2122
====================

# %%
#Multiline string literal- triple double quote/ triple single quote
c="""
Welcome to Python
----------------
Lets start variables
--------------------
Then Operators
===================
++++++++++++++++++++++
========================"""
print(c)
# Out:
# Welcome to Python
# ----------------
# Lets start variables
# --------------------
# Then Operators
# ...
# ++++++++++++++++++++++
# ...

# %%
#Multiline string literal- triple double quote/ triple single quote
c='''
Welcome to Python
----------------
Lets start variables
--------------------
Then Operators
===================
++++++++++++++++++++++
========================'''
print(c)
# Out:
# Welcome to Python
# ----------------
# Lets start variables
# --------------------
# Then Operators
# ...
# ++++++++++++++++++++++
# ...

# %%
print(c)
# Out:
# Welcome to Python
# ----------------
# Lets start variables
# --------------------
# Then Operators
# ...
# ++++++++++++++++++++++
# ...

# %%
print(f"""About Me
===================
Iam {name}
Working in {city}
with cost {cost}
===================
    """)
# Out:
# About Me
# ...
# Iam Theeba
# Working in Bglore
# with cost 22222.66
# ...

# %%
help(str.format)  # format method of str class
# Out:
# Help on method_descriptor:
#
# format(self, /, *args, **kwargs) unbound builtins.str method
#     Return a formatted version of the string, using substitutions from args and kwargs.
#     The substitutions are identified by braces ('{' and '}').

# %%
s="python"
print(type(s))
# Out:
# <class 'str'>

# %%
no=500
unit="GB"
#size=no+unit
print(no+unit)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 4
#       2 unit="GB"
#       3 #size=no+unit
# ----> 4 print(no+unit)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
str(no)  # str()- converts int/float/byte/bool  to str
print(type(no))
print(type(str(no)))
size=str(no)+unit
print(size)
#or
print(str(no)+unit)
# Out:
# <class 'int'>
# <class 'str'>
# 500GB
# 500GB

# %%
str
|---+ concatenation operator    str + str
|--- * repetation      str * int

# %%
print("="*100)

# %%
str
|----- immutable
|---- collection of char

" p y t h o n "
  | | | | | |
  0 1 2 3 4 5  index
 ....    -2  -1

stringname[index]--> charcter

# %%
s="Python"
print(id(s))
# Out:
# 2689476677184

# %%
s="python"
print(id(s))
# Out:
# 2689475471680

# %%
fdisk="xfs"
print(fdisk[2])  # positive indexing
print(fdisk[-1])  # negative indexing
# Out:
# s
# s

# %%
s="s:aix:root:Host01:event:4"
s1="s:aix:root:Host01:event:6"
print(s[-1])
print(s1[-1])
# Out:
# 4
# 6

# %%
len(s) # len- total no. of elements in collection
# Out:
# 25

# %%
# slicing
# syntax:-
#strname[n:m] extracts the charcter from nth index to (m-1) index 

s="Python Programming"
print(s[0:6])
# Out:
# Python

# %%
print(s[4:6])
# Out:
# on

# %%
print(s[4:])
# Out:
# on Programming

# %%
print(s[:6])
# Out:
# Python

# %%
greet="Hai"
print(greet[0:len(s)])
# Out:
# Hai

# %%
print(greet[-2:])
# Out:
# ai

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to 'utf-8'.
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getitem__(self, key, /)
# ...

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
s="The\tis\tabout\tPython"
print(s)
# Out:
# The	is	about	Python

# %%
filenam="E:\\Python\\f1.py"

# %%
s="\thello\nAll"
print(s)
print(s.strip())
# Out:
# 	hello
# All
# hello
# All

# %%
hostname=" Host01 \nHai"
print(hostname.lstrip())
# Out:
# Host01
# Hai

# %%
s="Arun:Bglore:254325:Production"
s.split(":")   # Single str--> List of Str
# Out:
# ['Arun', 'Bglore', '254325', 'Production']

# %%
s.split()   # no delimeter
# Out:
# ['Arun:Bglore:254325:Production']

# %%
L=['Arun', 'Bglore', '254325', 'Production']  # List of elements separated by comma, enclosed by []
print(type(L))
# Out:
# <class 'list'>

# %%
len(L)
# Out:
# 4

# %%
# ['Arun', 'Bglore', '254325', 'Production']
#   0        1         2           3
#   -4       -3       -2          -1 
# listname[index] -> fetch element from List
print(L[0])
print(L[-4])
# Out:
# Arun
# Arun

# %%
print(len(L[0]))  # No of charcater in "Arun"
print(len(L[-4]))
# Out:
# 4
# 4

# %%
L[2:]
# Out:
# ['254325', 'Production']

# %%
# str                               VS   List
# collection of char                     collection of elements
# index  -order                          index - ordered
# slicing                                slicing
# methods                                methods

# immutable-cant modify                  mutable-can modify

# %%
L
# Out:
# ['Arun', 'Bglore', '254325', 'Production']

# %%
# How to modify existing List element
L[3] = "Sales"   # Listname[index]="Newvalue"
L
# Out:
# ['Arun', 'Bglore', '254325', 'Sales']

# %%
L[100]="HR"
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 L[100]="HR"
#
# IndexError: list assignment index out of range

# %%
L=[100,2.444, True, 'DATA', b'data', [1,2,3,4]]
print(L)
# Out:
# [100, 2.444, True, 'DATA', b'data', [1, 2, 3, 4]]

# %%
L[-1]   # Listname[index]
# Out:
# [1, 2, 3, 4]

# %%
L[-1][1]
# Out:
# 2

# %%
L=[["macOS","WinX","Ubuntu"],["C","C++","JAVA"]]
print(L[0])
print(L[0][1])
# Out:
# ['macOS', 'WinX', 'Ubuntu']
# WinX

# %%
L=[["macOS","WinX","Ubuntu"],["C","C++","JAVA"]]
# Replace "C++" with "Ruby"

# %%
L[-1][1]="Ruby"
print(L)
# Out:
# [['macOS', 'WinX', 'Ubuntu'], ['C', 'Ruby', 'JAVA']]

# %%
L=[]
L.append("DATA1")
print(L)
L.append("DATA2")
print(L)
# Out:
# ['DATA1']
# ['DATA1', 'DATA2']

# %%
L.insert(1,"DATA3")  # add element at index
print(L)
# Out:
# ['DATA1', 'DATA3', 'DATA2']

# %%
L.pop(2)
# Out:
# 'DATA2'

# %%
L
# Out:
# ['DATA1', 'DATA3']

# %%
help(list)   #  or help([])    or help(L)
# Out:
# Help on class list in module builtins:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, index, /)
#  |      Return self[index].
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...

# %%
L=[1,2,3,1,2,1,2,1]  # mutable, allows duplicates
L
# Out:
# [1, 2, 3, 1, 2, 1, 2, 1]

# %%
L.remove(1)  # 1st occurence of 1 removed
L
# Out:
# [2, 3, 2, 1, 2, 1]

# %%
L=[2,7,1,3,20]
L.sort()  # sorts original list
L
# Out:
# [1, 2, 3, 7, 20]

# %%
L=[2,7,1,3,20]
L.sort(reverse=True)
L
# Out:
# [20, 7, 3, 2, 1]

# %%
name= input("Enter the name")
# Out:
# Enter the name Hari

# %%
print(name)
print(type(name))
# Out:
# Hari
# <class 'str'>

# %%
no=input("Enter the no")
print(no,type(no))
# Out:
# Enter the no 6432634
# 6432634 <class 'str'>

# %%
#int(), float()

# %%
no=int(input("Enter the no"))
print(no,type(no))
# Out:
# Enter the no 233232
# 233232 <class 'int'>

# %%
L=["Data1","Data2","DATA3"]
# in - membership operator
"Data1" in L    # member in Collection  -> true/ false
# Out:
# True

# %%
L1=[1,2,3]
L2=["os","db","tools"]
L1+L2
# Out:
# [1, 2, 3, 'os', 'db', 'tools']

# %%
# Tuple
#=======
List                           VS                 Tuple
[]                                                ()

collection of elmts                               ""
mutable                                           immutable
ordered- index                                     ordered- index
indexing,slicing                                   ""
duplicate allowed                                  " "

# %%
T=()   # empty Tuple
print(T,type(T))
# Out:
# () <class 'tuple'>

# %%
T=(1,2,3)
print(T, type(T))
# Out:
# (1, 2, 3) <class 'tuple'>

# %%
T=(10,20,30,10,10,10)
print(T)
# Out:
# (10, 20, 30, 10, 10, 10)

# %%
help(())
# Out:
# Help on tuple object:
#
# class tuple(object)
#  |  tuple(iterable=(), /)
#  |
#  |  Built-in immutable sequence.
#  |
#  |  If no argument is given, the constructor returns an empty tuple.
#  |  If iterable is specified the tuple is initialized from iterable's items.
#  |
#  |  If the argument is a tuple, the return value is the same object.
#  |
#  |  Built-in subclasses:
#  |      asyncgen_hooks
#  |      UnraisableHookArgs
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
# ...

# %%
T.count(10)
# Out:
# 4

# %%
T
# Out:
# (10, 20, 30, 10, 10, 10)

# %%
T.index(30)
# Out:
# 2

# %%
T.index(10)
# Out:
# 0

# %%
T.index(100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 T.index(100)
#
# ValueError: tuple.index(x): x not in tuple

# %%
help(T.index)
# Out:
# Help on built-in function index:
#
# index(value, start=0, stop=9223372036854775807, /) method of builtins.tuple instance
#     Return first index of value.
#
#     Raises ValueError if the value is not present.

# %%
T
# Out:
# (10, 20, 30, 10, 10, 10)

# %%
L= list(T)  # list() converts tuple to list
L.append(100)
T=tuple(L)    # tuple() converts list to tuple
T
# Out:
# (10, 20, 30, 10, 10, 10, 100)

# %%
T.count(10)
# Out:
# 4

# %%
len(T)
# Out:
# 7

# %%
Keyboard<STDIN>                      Python Script                                 Monitor<STDOUT>
-------------------------------------->   |     ------------------------------------->
input()                                   |                                    print()
                                          |
                                          Storage<FILE>

# %%
# 1. Read a input  from Keyboard, write to File
# 2. Read data from File , displaying to Monitor
# 3. Read data from <ONEFILE>, write data to <ANOTHERFILE>

# %%
fd= open("E:\\OU-BootCamp\\employee.txt")   #  return file descriptor / file Object
fd
# Out:
# <_io.TextIOWrapper name='E:\\OU-BootCamp\\employee.txt' mode='r' encoding='cp1252'>

# %%
s=fd.read()   # entire content read as a single str

# %%
print(s,type(s))
# Out:
# 101,Arun,sales,bengaluru,13222
# 102,Geetha,sales,HYdbd,3322
# 103,Hari,prod,kolkata,66267 <class 'str'>

# %%
s
# Out:
# '101,Arun,sales,bengaluru,13222\n102,Geetha,sales,HYdbd,3322\n103,Hari,prod,kolkata,66267'

# %%
# Read file content into List

fd= open("E:\\OU-BootCamp\\employee.txt") 
L=fd.readlines()    # read content as List
print(L,type(L))
# Out:
# ['101,Arun,sales,bengaluru,13222\n', '102,Geetha,sales,HYdbd,3322\n', '103,Hari,prod,kolkata,66267'] <class 'list'>

# %%
s=L[0]
s1= s.strip()
s2=s1.split(",")   # single str-> List of str
print(s2)
print(f"{s2[1]}  works in {s2[2]} department")
# Out:
# ['101', 'Arun', 'sales', 'bengaluru', '13222']
# Arun  works in sales department

# %%
# Multiple Initialization
# variable1,variable2.... = collection
print(s2)
id,name,dept,city,cost = s2   # Multiple Initialization
print(f" {name} working in {city} with cost {cost} ")
# Out:
# ['101', 'Arun', 'sales', 'bengaluru', '13222']
#  Arun working in bengaluru with cost 13222

# %%
a,b,c = 10,20,30
def f():
    return 10,

print(type(f()))
print(type(f))
# Out:
# <class 'tuple'>
# <class 'function'>

# %%
fd= open("E:\\OU-BootCamp\\New_employee.txt", "w") # write mode
fd.write("DATA")  # write method accepts Single Str as input
fd.close()

# %%
with open("E:\\OU-BootCamp\\New_employee.txt", "w") as fd: # create and write
    fd.write("DATA")

# %%
fd= open("E:\\OU-BootCamp\\New_employee.txt", "r")
s=fd.read()
print(s)
fd.close()
# Out:
# DATA

# %%
# employee.txt file content
with open("E:\\OU-BootCamp\\employee.txt", "r") as fd: # append mode
    print(fd.read())
# Out:
# 101,Arun,sales,bengaluru,13222
# 102,Geetha,sales,HYdbd,3322
# 103,Hari,prod,kolkata,66267

# %%
# append to existing file
with open("E:\\OU-BootCamp\\employee.txt", "a") as fd: # append mode
    fd.write("\n110,Gowri,Prod,Hyderabad,33232")

# %%
# employee.txt file content
with open("E:\\OU-BootCamp\\employee.txt", "r") as fd: # append mode
    print(fd.read())
# Out:
# 101,Arun,sales,bengaluru,13222
# 102,Geetha,sales,HYdbd,3322
# 103,Hari,prod,kolkata,66267
# 110,Gowri,Prod,Hyderabad,33232
